# %%
# !pip install torch numpy
# Out:
# Collecting torch
#   Using cached torch-2.5.1-cp311-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Requirement already satisfied: numpy in /Users/swl/Documents/data-analysis/advanced/Lab9/notebooks/netflixApp/.conda/lib/python3.11/site-packages (1.26.4)
# Collecting filelock (from torch)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/swl/Documents/data-analysis/advanced/Lab9/notebooks/netflixApp/.conda/lib/python3.11/site-packages (from torch) (4.12.2)
# Collecting networkx (from torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /Users/swl/Documents/data-analysis/advanced/Lab9/notebooks/netflixApp/.conda/lib/python3.11/site-packages (from torch) (3.1.4)
# Collecting fsspec (from torch)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/swl/Documents/data-analysis/advanced/Lab9/notebooks/netflixApp/.conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Using cached torch-2.5.1-cp311-none-macosx_11_0_arm64.whl (63.9 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.2 MB/s eta 0:00:0000:0100:01
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch
# Successfully installed filelock-3.16.1 fsspec-2024.12.0 mpmath-1.3.0 networkx-3.4.2 sympy-1.13.1 torch-2.5.1

# %% [markdown]
# ### In this case, the environment is Tic-Tac-Toe. We will define the game environment in a way that can be interacted with by the DQN agent.

# %%
import random
import numpy as np

# %%
class TicTacToe:
    def __init__(self):
        self.board = np.zeros((3, 3), dtype=int)  # A 3x3 grid
        self.current_player = 1  # Player 1 starts (X)

    def clone(self):
        """Returns a new instance with the current board state."""
        new_game = TicTacToe()
        new_game.board = np.copy(self.board)
        new_game.current_player = self.current_player
        return new_game

    def reset(self):
        """Reset the game board."""
        self.board = np.zeros((3, 3), dtype=int)
        self.current_player = 1
        return self.board.flatten()  # Return the flattened state (1D array)

    def available_moves(self):
        """Get available moves."""
        return [(i, j) for i in range(3) for j in range(3) if self.board[i, j] == 0]

    def make_move(self, row, col, player):
        """Make a move for the current player."""
        if self.board[row, col] == 0:
            self.board[row, col] = player
            return True
        return False

    def check_winner(self):
        """Check if there's a winner."""
        for i in range(3):
            if abs(sum(self.board[i, :])) == 3: return 1 if self.board[i, 0] == 1 else -1
            if abs(sum(self.board[:, i])) == 3: return 1 if self.board[0, i] == 1 else -1
        if abs(sum(np.diag(self.board))) == 3: return 1 if self.board[0, 0] == 1 else -1
        if abs(sum(np.diag(np.fliplr(self.board)))) == 3: return 1 if self.board[0, 2] == 1 else -1
        if len(self.available_moves()) == 0: return 0  # Draw
        return None  # Game still in progress

    def display_board(self):
        """Display the game board."""
        for row in self.board:
            print(" | ".join(['X' if x == 1 else 'O' if x == -1 else ' ' for x in row]))
            print("-" * 9)

# %% [markdown]
# ## Define the DQN Model
# ### The agent will use a deep neural network to approximate the Q-value function. The network will take the current game state as input and output the Q-values for each possible action.
# ### We’ll define a simple feed-forward neural network using PyTorch.

# %%
class Node:
    def __init__(self, state, parent=None, player=1):
        self.state = state  # TicTacToe instance
        self.parent = parent  # Parent node
        self.children = []  # List of child nodes
        self.visits = 0  # Number of times this node has been visited
        self.wins = 0  # Number of wins from this node
        self.player = player  # Player who made the move (-1 or 1)

    def is_fully_expanded(self):
        """Check if all possible moves have been explored."""
        return len(self.children) == len(self.state.available_moves())

    def add_child(self, child_node):
        self.children.append(child_node)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)  # First fully connected layer
        self.fc2 = nn.Linear(128, 128)  # Second fully connected layer
        self.fc3 = nn.Linear(128, output_dim)  # Output layer for Q-values

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)  # Q-values for each action

# %% [markdown]
# ## Define the Experience Replay Buffer
# ## The experience replay buffer stores the agent's experiences (state, action, reward, next_state, done). The agent will sample random mini-batches from the buffer to train the DQN. This helps to break the correlation between consecutive experiences and stabilizes training.

# %%
class ReplayBuffer:
    def __init__(self, capacity=10000000):
        self.buffer = []
        self.capacity = capacity
        self.size = 0

    def push(self, experience):
        """Store an experience in the buffer."""
        if self.size < self.capacity:
            self.buffer.append(experience)
        else:
            self.buffer[self.size % self.capacity] = experience
        self.size += 1

    def sample(self, batch_size):
        """Sample a random mini-batch from the buffer."""
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# ## Define the Agent
# ### The DQN agent interacts with the environment, stores experiences in the replay buffer, and trains the model. The agent will choose actions using an epsilon-greedy policy (exploration vs exploitation).

# %%
class DQNAgent:
    def __init__(self, input_dim, output_dim, epsilon=0.2, gamma=0.99, batch_size=64, lr=1e-3):
        self.model = DQN(input_dim, output_dim)
        self.target_model = DQN(input_dim, output_dim)  # Target model for stable learning
        self.target_model.load_state_dict(self.model.state_dict())  # Initialize target model
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.epsilon = epsilon
        self.gamma = gamma
        self.batch_size = batch_size
        self.replay_buffer = ReplayBuffer()
        self.loss_fn = nn.MSELoss()
        self.encountered_states = set()  # Set to track seen states-action pairs

    def select_action(self, state):
        """Select an action using epsilon-greedy policy with only valid moves."""
        if random.random() < self.epsilon:
            # Random action, but only from valid moves
            valid_moves = [i for i in range(9) if state[i] == 0]
            return random.choice(valid_moves)
        else:
            # Convert the state to a tensor of shape [1, input_dim] for batch processing
            state_tensor = torch.FloatTensor(state).unsqueeze(0)  # Add batch dimension
            q_values = self.model(state_tensor)  # Get Q-values for all possible moves

            # Find valid moves and filter out invalid ones
            valid_moves = [i for i in range(9) if state[i] == 0]

            # Get Q-values corresponding to valid moves
            valid_q_values = q_values[0, valid_moves]  # Get the Q-values for valid moves (1D tensor)

            # Select the valid move with the highest Q-value
            best_move_idx = torch.argmax(valid_q_values).item()

            # Map the best move back to the original index of the valid move
            return valid_moves[best_move_idx]

    def store_experience(self, state, action, reward, next_state, done):
        """Store the experience if it's not already in the encountered set."""
        state_action_pair = tuple(state.flatten()) + (action,)  # State-action pair
        if state_action_pair not in self.encountered_states:
            self.replay_buffer.push((state, action, reward, next_state, done))
            self.encountered_states.add(state_action_pair)  # Mark this pair as encountered

    def update_target_network(self):
        """Update target network with model's weights."""
        self.target_model.load_state_dict(self.model.state_dict())

    def train(self):
        """Train the DQN model using a batch from the replay buffer."""
        if len(self.replay_buffer) < self.batch_size:
            return  # Not enough data to train

        # Sample a batch of experiences
        batch = self.replay_buffer.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states_tensor = torch.FloatTensor(states)
        actions_tensor = torch.LongTensor(actions)
        rewards_tensor = torch.FloatTensor(rewards)
        next_states_tensor = torch.FloatTensor(next_states)
        dones_tensor = torch.BoolTensor(dones)

        # Q-values for current states
        q_values = self.model(states_tensor)
        q_values = q_values.gather(1, actions_tensor.unsqueeze(1)).squeeze(1)

        # Q-values for next states
        next_q_values = self.target_model(next_states_tensor)
        next_q_values_max = next_q_values.max(1)[0]  # Max Q-value for each next state

        # Compute the target Q-value
        target_q_values = rewards_tensor + (self.gamma * next_q_values_max * ~dones_tensor)

        # Compute loss
        loss = self.loss_fn(q_values, target_q_values)
        
        # Backpropagate and optimize
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# ## Training the DQN Agent
# Now we’ll set up the training loop. In each episode:
#
# The agent interacts with the environment.
# The agent selects actions using its policy (epsilon-greedy).
# The agent stores experiences in the replay buffer.
# The agent trains the DQN model by sampling from the replay buffer.

# %%
def train_dqn_agent(episodes=10000):
    env = TicTacToe()
    agent = DQNAgent(input_dim=9, output_dim=9)  # 9 possible moves for a 3x3 Tic-Tac-Toe board

    for episode in range(episodes):
        state = env.reset()
        done = False

        while not done:
            action = agent.select_action(state)
            row, col = divmod(action, 3)
            valid_move = env.make_move(row, col, env.current_player)  # Pass the current player

            if valid_move:
                winner = env.check_winner()
                if winner is not None:
                    reward = 10 if winner == 1 else -10 if winner == -1 else 0
                    done = True
                else:
                    reward = 0
                next_state = env.board.flatten()

                agent.store_experience(state, action, reward, next_state, done)
                state = next_state

                agent.train()  # Train the model

        # Update target network every 10 episodes
        if episode % 10 == 0:
            agent.update_target_network()

        print(f"Episode {episode + 1} completed.")
    # After training in train_dqn_agent
    torch.save(agent.model.state_dict(), 'tictactoe_dqn_model.pth')
train_dqn_agent()
# Out:
# Episode 1 completed.
# Episode 2 completed.
# Episode 3 completed.
# Episode 4 completed.
# Episode 5 completed.
# Episode 6 completed.
# Episode 7 completed.
# Episode 8 completed.
# Episode 9 completed.
# Episode 10 completed.
# Episode 11 completed.
# Episode 12 completed.
# Episode 13 completed.
# Episode 14 completed.
# Episode 15 completed.
# Episode 16 completed.
# Episode 17 completed.
# Episode 18 completed.
# Episode 19 completed.
# Episode 20 completed.
# Episode 21 completed.
# Episode 22 completed.
# Episode 23 completed.
# Episode 24 completed.
# Episode 25 completed.
# Episode 26 completed.
# Episode 27 completed.
# Episode 28 completed.
# Episode 29 completed.
# Episode 30 completed.
# Episode 31 completed.
# Episode 32 completed.
# Episode 33 completed.
# Episode 34 completed.
# Episode 35 completed.
# Episode 36 completed.
# Episode 37 completed.
# Episode 38 completed.
# Episode 39 completed.
# Episode 40 completed.
# Episode 41 completed.
# Episode 42 completed.
# Episode 43 completed.
# Episode 44 completed.
# Episode 45 completed.
# Episode 46 completed.
# Episode 47 completed.
# Episode 48 completed.
# Episode 49 completed.
# Episode 50 completed.
# Episode 51 completed.
# Episode 52 completed.
# Episode 53 completed.
# Episode 54 completed.
# Episode 55 completed.
# Episode 56 completed.
# Episode 57 completed.
# Episode 58 completed.
# Episode 59 completed.
# Episode 60 completed.
# Episode 61 completed.
# Episode 62 completed.
# Episode 63 completed.
# Episode 64 completed.
# Episode 65 completed.
# Episode 66 completed.
# Episode 67 completed.
# Episode 68 completed.
# Episode 69 completed.
# Episode 70 completed.
# Episode 71 completed.
# Episode 72 completed.
# Episode 73 completed.
# Episode 74 completed.
# Episode 75 completed.
# Episode 76 completed.
# Episode 77 completed.
# Episode 78 completed.
# Episode 79 completed.
# Episode 80 completed.
# Episode 81 completed.
# Episode 82 completed.
# Episode 83 completed.
# Episode 84 completed.
# Episode 85 completed.
# Episode 86 completed.
# Episode 87 completed.
# Episode 88 completed.
# Episode 89 completed.
# Episode 90 completed.
# Episode 91 completed.
# Episode 92 completed.
# Episode 93 completed.
# Episode 94 completed.
# Episode 95 completed.
# Episode 96 completed.
# Episode 97 completed.
# Episode 98 completed.
# Episode 99 completed.
# Episode 100 completed.
# Episode 101 completed.
# Episode 102 completed.
# Episode 103 completed.
# Episode 104 completed.
# Episode 105 completed.
# Episode 106 completed.
# Episode 107 completed.
# Episode 108 completed.
# Episode 109 completed.
# Episode 110 completed.
# Episode 111 completed.
# Episode 112 completed.
# Episode 113 completed.
# Episode 114 completed.
# Episode 115 completed.
# Episode 116 completed.
# Episode 117 completed.
# Episode 118 completed.
# Episode 119 completed.
# Episode 120 completed.
# Episode 121 completed.
# Episode 122 completed.
# Episode 123 completed.
# Episode 124 completed.
# Episode 125 completed.
# Episode 126 completed.
# Episode 127 completed.
# Episode 128 completed.
# Episode 129 completed.
# Episode 130 completed.
# Episode 131 completed.
# Episode 132 completed.
# Episode 133 completed.
# Episode 134 completed.
# Episode 135 completed.
# Episode 136 completed.
# Episode 137 completed.
# Episode 138 completed.
# Episode 139 completed.
# Episode 140 completed.
# Episode 141 completed.
# Episode 142 completed.
# Episode 143 completed.
# Episode 144 completed.
# Episode 145 completed.
# Episode 146 completed.
# Episode 147 completed.
# Episode 148 completed.
# Episode 149 completed.
# Episode 150 completed.
# Episode 151 completed.
# Episode 152 completed.
# Episode 153 completed.
# Episode 154 completed.
# Episode 155 completed.
# Episode 156 completed.
# Episode 157 completed.
# Episode 158 completed.
# Episode 159 completed.
# Episode 160 completed.
# Episode 161 completed.
# Episode 162 completed.
# Episode 163 completed.
# Episode 164 completed.
# Episode 165 completed.
# Episode 166 completed.
# Episode 167 completed.
# Episode 168 completed.
# Episode 169 completed.
# Episode 170 completed.
# Episode 171 completed.
# Episode 172 completed.
# Episode 173 completed.
# Episode 174 completed.
# Episode 175 completed.
# Episode 176 completed.
# Episode 177 completed.
# Episode 178 completed.
# Episode 179 completed.
# Episode 180 completed.
# Episode 181 completed.
# Episode 182 completed.
# Episode 183 completed.
# Episode 184 completed.
# Episode 185 completed.
# Episode 186 completed.
# Episode 187 completed.
# Episode 188 completed.
# Episode 189 completed.
# Episode 190 completed.
# Episode 191 completed.
# Episode 192 completed.
# Episode 193 completed.
# Episode 194 completed.
# Episode 195 completed.
# Episode 196 completed.
# Episode 197 completed.
# Episode 198 completed.
# Episode 199 completed.
# Episode 200 completed.
# Episode 201 completed.
# Episode 202 completed.
# Episode 203 completed.
# Episode 204 completed.
# Episode 205 completed.
# Episode 206 completed.
# Episode 207 completed.
# Episode 208 completed.
# Episode 209 completed.
# Episode 210 completed.
# Episode 211 completed.
# Episode 212 completed.
# Episode 213 completed.
# Episode 214 completed.
# Episode 215 completed.
# Episode 216 completed.
# Episode 217 completed.
# Episode 218 completed.
# Episode 219 completed.
# Episode 220 completed.
# Episode 221 completed.
# Episode 222 completed.
# Episode 223 completed.
# Episode 224 completed.
# Episode 225 completed.
# Episode 226 completed.
# Episode 227 completed.
# Episode 228 completed.
# Episode 229 completed.
# Episode 230 completed.
# Episode 231 completed.
# Episode 232 completed.
# Episode 233 completed.
# Episode 234 completed.
# Episode 235 completed.
# Episode 236 completed.
# Episode 237 completed.
# Episode 238 completed.
# Episode 239 completed.
# Episode 240 completed.
# Episode 241 completed.
# Episode 242 completed.
# Episode 243 completed.
# Episode 244 completed.
# Episode 245 completed.
# Episode 246 completed.
# Episode 247 completed.
# Episode 248 completed.
# Episode 249 completed.
# Episode 250 completed.
# Episode 251 completed.
# Episode 252 completed.
# Episode 253 completed.
# Episode 254 completed.
# Episode 255 completed.
# Episode 256 completed.
# Episode 257 completed.
# Episode 258 completed.
# Episode 259 completed.
# Episode 260 completed.
# Episode 261 completed.
# Episode 262 completed.
# Episode 263 completed.
# Episode 264 completed.
# Episode 265 completed.
# Episode 266 completed.
# Episode 267 completed.
# Episode 268 completed.
# Episode 269 completed.
# Episode 270 completed.
# Episode 271 completed.
# Episode 272 completed.
# Episode 273 completed.
# Episode 274 completed.
# Episode 275 completed.
# Episode 276 completed.
# Episode 277 completed.
# Episode 278 completed.
# Episode 279 completed.
# Episode 280 completed.
# Episode 281 completed.
# Episode 282 completed.
# Episode 283 completed.
# Episode 284 completed.
# Episode 285 completed.
# Episode 286 completed.
# Episode 287 completed.
# Episode 288 completed.
# Episode 289 completed.
# Episode 290 completed.
# Episode 291 completed.
# Episode 292 completed.
# Episode 293 completed.
# Episode 294 completed.
# Episode 295 completed.
# Episode 296 completed.
# Episode 297 completed.
# Episode 298 completed.
# Episode 299 completed.
# Episode 300 completed.
# Episode 301 completed.
# Episode 302 completed.
# Episode 303 completed.
# Episode 304 completed.
# Episode 305 completed.
# Episode 306 completed.
# Episode 307 completed.
# Episode 308 completed.
# Episode 309 completed.
# Episode 310 completed.
# Episode 311 completed.
# Episode 312 completed.
# Episode 313 completed.
# Episode 314 completed.
# Episode 315 completed.
# Episode 316 completed.
# Episode 317 completed.
# Episode 318 completed.
# Episode 319 completed.
# Episode 320 completed.
# Episode 321 completed.
# Episode 322 completed.
# Episode 323 completed.
# Episode 324 completed.
# Episode 325 completed.
# Episode 326 completed.
# Episode 327 completed.
# Episode 328 completed.
# Episode 329 completed.
# Episode 330 completed.
# Episode 331 completed.
# Episode 332 completed.
# Episode 333 completed.
# Episode 334 completed.
# Episode 335 completed.
# Episode 336 completed.
# Episode 337 completed.
# Episode 338 completed.
# Episode 339 completed.
# Episode 340 completed.
# Episode 341 completed.
# Episode 342 completed.
# Episode 343 completed.
# Episode 344 completed.
# Episode 345 completed.
# Episode 346 completed.
# Episode 347 completed.
# Episode 348 completed.
# Episode 349 completed.
# Episode 350 completed.
# Episode 351 completed.
# Episode 352 completed.
# Episode 353 completed.
# Episode 354 completed.
# Episode 355 completed.
# Episode 356 completed.
# Episode 357 completed.
# Episode 358 completed.
# Episode 359 completed.
# Episode 360 completed.
# Episode 361 completed.
# Episode 362 completed.
# Episode 363 completed.
# Episode 364 completed.
# Episode 365 completed.
# Episode 366 completed.
# Episode 367 completed.
# Episode 368 completed.
# Episode 369 completed.
# Episode 370 completed.
# Episode 371 completed.
# Episode 372 completed.
# Episode 373 completed.
# Episode 374 completed.
# Episode 375 completed.
# Episode 376 completed.
# Episode 377 completed.
# Episode 378 completed.
# Episode 379 completed.
# Episode 380 completed.
# Episode 381 completed.
# Episode 382 completed.
# Episode 383 completed.
# Episode 384 completed.
# Episode 385 completed.
# Episode 386 completed.
# Episode 387 completed.
# Episode 388 completed.
# Episode 389 completed.
# Episode 390 completed.
# Episode 391 completed.
# Episode 392 completed.
# Episode 393 completed.
# Episode 394 completed.
# Episode 395 completed.
# Episode 396 completed.
# Episode 397 completed.
# Episode 398 completed.
# Episode 399 completed.
# Episode 400 completed.
# Episode 401 completed.
# Episode 402 completed.
# Episode 403 completed.
# Episode 404 completed.
# Episode 405 completed.
# Episode 406 completed.
# Episode 407 completed.
# Episode 408 completed.
# Episode 409 completed.
# Episode 410 completed.
# Episode 411 completed.
# Episode 412 completed.
# Episode 413 completed.
# Episode 414 completed.
# Episode 415 completed.
# Episode 416 completed.
# Episode 417 completed.
# Episode 418 completed.
# Episode 419 completed.
# Episode 420 completed.
# Episode 421 completed.
# Episode 422 completed.
# Episode 423 completed.
# Episode 424 completed.
# Episode 425 completed.
# Episode 426 completed.
# Episode 427 completed.
# Episode 428 completed.
# Episode 429 completed.
# Episode 430 completed.
# Episode 431 completed.
# Episode 432 completed.
# Episode 433 completed.
# Episode 434 completed.
# Episode 435 completed.
# Episode 436 completed.
# Episode 437 completed.
# Episode 438 completed.
# Episode 439 completed.
# Episode 440 completed.
# Episode 441 completed.
# Episode 442 completed.
# Episode 443 completed.
# Episode 444 completed.
# Episode 445 completed.
# Episode 446 completed.
# Episode 447 completed.
# Episode 448 completed.
# Episode 449 completed.
# Episode 450 completed.
# Episode 451 completed.
# Episode 452 completed.
# Episode 453 completed.
# Episode 454 completed.
# Episode 455 completed.
# Episode 456 completed.
# Episode 457 completed.
# Episode 458 completed.
# Episode 459 completed.
# Episode 460 completed.
# Episode 461 completed.
# Episode 462 completed.
# Episode 463 completed.
# Episode 464 completed.
# Episode 465 completed.
# Episode 466 completed.
# Episode 467 completed.
# Episode 468 completed.
# Episode 469 completed.
# Episode 470 completed.
# Episode 471 completed.
# Episode 472 completed.
# Episode 473 completed.
# Episode 474 completed.
# Episode 475 completed.
# Episode 476 completed.
# Episode 477 completed.
# Episode 478 completed.
# Episode 479 completed.
# Episode 480 completed.
# Episode 481 completed.
# Episode 482 completed.
# Episode 483 completed.
# Episode 484 completed.
# Episode 485 completed.
# Episode 486 completed.
# Episode 487 completed.
# Episode 488 completed.
# Episode 489 completed.
# Episode 490 completed.
# Episode 491 completed.
# Episode 492 completed.
# Episode 493 completed.
# Episode 494 completed.
# Episode 495 completed.
# Episode 496 completed.
# Episode 497 completed.
# Episode 498 completed.
# Episode 499 completed.
# Episode 500 completed.
# Episode 501 completed.
# Episode 502 completed.
# Episode 503 completed.
# Episode 504 completed.
# Episode 505 completed.
# Episode 506 completed.
# Episode 507 completed.
# Episode 508 completed.
# Episode 509 completed.
# Episode 510 completed.
# Episode 511 completed.
# Episode 512 completed.
# Episode 513 completed.
# Episode 514 completed.
# Episode 515 completed.
# Episode 516 completed.
# Episode 517 completed.
# Episode 518 completed.
# Episode 519 completed.
# Episode 520 completed.
# Episode 521 completed.
# Episode 522 completed.
# Episode 523 completed.
# Episode 524 completed.
# Episode 525 completed.
# Episode 526 completed.
# Episode 527 completed.
# Episode 528 completed.
# Episode 529 completed.
# Episode 530 completed.
# Episode 531 completed.
# Episode 532 completed.
# Episode 533 completed.
# Episode 534 completed.
# Episode 535 completed.
# Episode 536 completed.
# Episode 537 completed.
# Episode 538 completed.
# Episode 539 completed.
# Episode 540 completed.
# Episode 541 completed.
# Episode 542 completed.
# Episode 543 completed.
# Episode 544 completed.
# Episode 545 completed.
# Episode 546 completed.
# Episode 547 completed.
# Episode 548 completed.
# Episode 549 completed.
# Episode 550 completed.
# Episode 551 completed.
# Episode 552 completed.
# Episode 553 completed.
# Episode 554 completed.
# Episode 555 completed.
# Episode 556 completed.
# Episode 557 completed.
# Episode 558 completed.
# Episode 559 completed.
# Episode 560 completed.
# Episode 561 completed.
# Episode 562 completed.
# Episode 563 completed.
# Episode 564 completed.
# Episode 565 completed.
# Episode 566 completed.
# Episode 567 completed.
# Episode 568 completed.
# Episode 569 completed.
# Episode 570 completed.
# Episode 571 completed.
# Episode 572 completed.
# Episode 573 completed.
# Episode 574 completed.
# Episode 575 completed.
# Episode 576 completed.
# Episode 577 completed.
# Episode 578 completed.
# Episode 579 completed.
# Episode 580 completed.
# Episode 581 completed.
# Episode 582 completed.
# Episode 583 completed.
# Episode 584 completed.
# Episode 585 completed.
# Episode 586 completed.
# Episode 587 completed.
# Episode 588 completed.
# Episode 589 completed.
# Episode 590 completed.
# Episode 591 completed.
# Episode 592 completed.
# Episode 593 completed.
# Episode 594 completed.
# Episode 595 completed.
# Episode 596 completed.
# Episode 597 completed.
# Episode 598 completed.
# Episode 599 completed.
# Episode 600 completed.
# Episode 601 completed.
# Episode 602 completed.
# Episode 603 completed.
# Episode 604 completed.
# Episode 605 completed.
# Episode 606 completed.
# Episode 607 completed.
# Episode 608 completed.
# Episode 609 completed.
# Episode 610 completed.
# Episode 611 completed.
# Episode 612 completed.
# Episode 613 completed.
# Episode 614 completed.
# Episode 615 completed.
# Episode 616 completed.
# Episode 617 completed.
# Episode 618 completed.
# Episode 619 completed.
# Episode 620 completed.
# Episode 621 completed.
# Episode 622 completed.
# Episode 623 completed.
# Episode 624 completed.
# Episode 625 completed.
# Episode 626 completed.
# Episode 627 completed.
# Episode 628 completed.
# Episode 629 completed.
# Episode 630 completed.
# Episode 631 completed.
# Episode 632 completed.
# Episode 633 completed.
# Episode 634 completed.
# Episode 635 completed.
# Episode 636 completed.
# Episode 637 completed.
# Episode 638 completed.
# Episode 639 completed.
# Episode 640 completed.
# Episode 641 completed.
# Episode 642 completed.
# Episode 643 completed.
# Episode 644 completed.
# Episode 645 completed.
# Episode 646 completed.
# Episode 647 completed.
# Episode 648 completed.
# Episode 649 completed.
# Episode 650 completed.
# Episode 651 completed.
# Episode 652 completed.
# Episode 653 completed.
# Episode 654 completed.
# Episode 655 completed.
# Episode 656 completed.
# Episode 657 completed.
# Episode 658 completed.
# Episode 659 completed.
# Episode 660 completed.
# Episode 661 completed.
# Episode 662 completed.
# Episode 663 completed.
# Episode 664 completed.
# Episode 665 completed.
# Episode 666 completed.
# Episode 667 completed.
# Episode 668 completed.
# Episode 669 completed.
# Episode 670 completed.
# Episode 671 completed.
# Episode 672 completed.
# Episode 673 completed.
# Episode 674 completed.
# Episode 675 completed.
# Episode 676 completed.
# Episode 677 completed.
# Episode 678 completed.
# Episode 679 completed.
# Episode 680 completed.
# Episode 681 completed.
# Episode 682 completed.
# Episode 683 completed.
# Episode 684 completed.
# Episode 685 completed.
# Episode 686 completed.
# Episode 687 completed.
# Episode 688 completed.
# Episode 689 completed.
# Episode 690 completed.
# Episode 691 completed.
# Episode 692 completed.
# Episode 693 completed.
# Episode 694 completed.
# Episode 695 completed.
# Episode 696 completed.
# Episode 697 completed.
# Episode 698 completed.
# Episode 699 completed.
# Episode 700 completed.
# Episode 701 completed.
# Episode 702 completed.
# Episode 703 completed.
# Episode 704 completed.
# Episode 705 completed.
# Episode 706 completed.
# Episode 707 completed.
# Episode 708 completed.
# Episode 709 completed.
# Episode 710 completed.
# Episode 711 completed.
# Episode 712 completed.
# Episode 713 completed.
# Episode 714 completed.
# Episode 715 completed.
# Episode 716 completed.
# Episode 717 completed.
# Episode 718 completed.
# Episode 719 completed.
# Episode 720 completed.
# Episode 721 completed.
# Episode 722 completed.
# Episode 723 completed.
# Episode 724 completed.
# Episode 725 completed.
# Episode 726 completed.
# Episode 727 completed.
# Episode 728 completed.
# Episode 729 completed.
# Episode 730 completed.
# Episode 731 completed.
# Episode 732 completed.
# Episode 733 completed.
# Episode 734 completed.
# Episode 735 completed.
# Episode 736 completed.
# Episode 737 completed.
# Episode 738 completed.
# Episode 739 completed.
# Episode 740 completed.
# Episode 741 completed.
# Episode 742 completed.
# Episode 743 completed.
# Episode 744 completed.
# Episode 745 completed.
# Episode 746 completed.
# Episode 747 completed.
# Episode 748 completed.
# Episode 749 completed.
# Episode 750 completed.
# Episode 751 completed.
# Episode 752 completed.
# Episode 753 completed.
# Episode 754 completed.
# Episode 755 completed.
# Episode 756 completed.
# Episode 757 completed.
# Episode 758 completed.
# Episode 759 completed.
# Episode 760 completed.
# Episode 761 completed.
# Episode 762 completed.
# Episode 763 completed.
# Episode 764 completed.
# Episode 765 completed.
# Episode 766 completed.
# Episode 767 completed.
# Episode 768 completed.
# Episode 769 completed.
# Episode 770 completed.
# Episode 771 completed.
# Episode 772 completed.
# Episode 773 completed.
# Episode 774 completed.
# Episode 775 completed.
# Episode 776 completed.
# Episode 777 completed.
# Episode 778 completed.
# Episode 779 completed.
# Episode 780 completed.
# Episode 781 completed.
# Episode 782 completed.
# Episode 783 completed.
# Episode 784 completed.
# Episode 785 completed.
# Episode 786 completed.
# Episode 787 completed.
# Episode 788 completed.
# Episode 789 completed.
# Episode 790 completed.
# Episode 791 completed.
# Episode 792 completed.
# Episode 793 completed.
# Episode 794 completed.
# Episode 795 completed.
# Episode 796 completed.
# Episode 797 completed.
# Episode 798 completed.
# Episode 799 completed.
# Episode 800 completed.
# Episode 801 completed.
# Episode 802 completed.
# Episode 803 completed.
# Episode 804 completed.
# Episode 805 completed.
# Episode 806 completed.
# Episode 807 completed.
# Episode 808 completed.
# Episode 809 completed.
# Episode 810 completed.
# Episode 811 completed.
# Episode 812 completed.
# Episode 813 completed.
# Episode 814 completed.
# Episode 815 completed.
# Episode 816 completed.
# Episode 817 completed.
# Episode 818 completed.
# Episode 819 completed.
# Episode 820 completed.
# Episode 821 completed.
# Episode 822 completed.
# Episode 823 completed.
# Episode 824 completed.
# Episode 825 completed.
# Episode 826 completed.
# Episode 827 completed.
# Episode 828 completed.
# Episode 829 completed.
# Episode 830 completed.
# Episode 831 completed.
# Episode 832 completed.
# Episode 833 completed.
# Episode 834 completed.
# Episode 835 completed.
# Episode 836 completed.
# Episode 837 completed.
# Episode 838 completed.
# Episode 839 completed.
# Episode 840 completed.
# Episode 841 completed.
# Episode 842 completed.
# Episode 843 completed.
# Episode 844 completed.
# Episode 845 completed.
# Episode 846 completed.
# Episode 847 completed.
# Episode 848 completed.
# Episode 849 completed.
# Episode 850 completed.
# Episode 851 completed.
# Episode 852 completed.
# Episode 853 completed.
# Episode 854 completed.
# Episode 855 completed.
# Episode 856 completed.
# Episode 857 completed.
# Episode 858 completed.
# Episode 859 completed.
# Episode 860 completed.
# Episode 861 completed.
# Episode 862 completed.
# Episode 863 completed.
# Episode 864 completed.
# Episode 865 completed.
# Episode 866 completed.
# Episode 867 completed.
# Episode 868 completed.
# Episode 869 completed.
# Episode 870 completed.
# Episode 871 completed.
# Episode 872 completed.
# Episode 873 completed.
# Episode 874 completed.
# Episode 875 completed.
# Episode 876 completed.
# Episode 877 completed.
# Episode 878 completed.
# Episode 879 completed.
# Episode 880 completed.
# Episode 881 completed.
# Episode 882 completed.
# Episode 883 completed.
# Episode 884 completed.
# Episode 885 completed.
# Episode 886 completed.
# Episode 887 completed.
# Episode 888 completed.
# Episode 889 completed.
# Episode 890 completed.
# Episode 891 completed.
# Episode 892 completed.
# Episode 893 completed.
# Episode 894 completed.
# Episode 895 completed.
# Episode 896 completed.
# Episode 897 completed.
# Episode 898 completed.
# Episode 899 completed.
# Episode 900 completed.
# Episode 901 completed.
# Episode 902 completed.
# Episode 903 completed.
# Episode 904 completed.
# Episode 905 completed.
# Episode 906 completed.
# Episode 907 completed.
# Episode 908 completed.
# Episode 909 completed.
# Episode 910 completed.
# Episode 911 completed.
# Episode 912 completed.
# Episode 913 completed.
# Episode 914 completed.
# Episode 915 completed.
# Episode 916 completed.
# Episode 917 completed.
# Episode 918 completed.
# Episode 919 completed.
# Episode 920 completed.
# Episode 921 completed.
# Episode 922 completed.
# Episode 923 completed.
# Episode 924 completed.
# Episode 925 completed.
# Episode 926 completed.
# Episode 927 completed.
# Episode 928 completed.
# Episode 929 completed.
# Episode 930 completed.
# Episode 931 completed.
# Episode 932 completed.
# Episode 933 completed.
# Episode 934 completed.
# Episode 935 completed.
# Episode 936 completed.
# Episode 937 completed.
# Episode 938 completed.
# Episode 939 completed.
# Episode 940 completed.
# Episode 941 completed.
# Episode 942 completed.
# Episode 943 completed.
# Episode 944 completed.
# Episode 945 completed.
# Episode 946 completed.
# Episode 947 completed.
# Episode 948 completed.
# Episode 949 completed.
# Episode 950 completed.
# Episode 951 completed.
# Episode 952 completed.
# Episode 953 completed.
# Episode 954 completed.
# Episode 955 completed.
# Episode 956 completed.
# Episode 957 completed.
# Episode 958 completed.
# Episode 959 completed.
# Episode 960 completed.
# Episode 961 completed.
# Episode 962 completed.
# Episode 963 completed.
# Episode 964 completed.
# Episode 965 completed.
# Episode 966 completed.
# Episode 967 completed.
# Episode 968 completed.
# Episode 969 completed.
# Episode 970 completed.
# Episode 971 completed.
# Episode 972 completed.
# Episode 973 completed.
# Episode 974 completed.
# Episode 975 completed.
# Episode 976 completed.
# Episode 977 completed.
# Episode 978 completed.
# Episode 979 completed.
# Episode 980 completed.
# Episode 981 completed.
# Episode 982 completed.
# Episode 983 completed.
# Episode 984 completed.
# Episode 985 completed.
# Episode 986 completed.
# Episode 987 completed.
# Episode 988 completed.
# Episode 989 completed.
# Episode 990 completed.
# Episode 991 completed.
# Episode 992 completed.
# Episode 993 completed.
# Episode 994 completed.
# Episode 995 completed.
# Episode 996 completed.
# Episode 997 completed.
# Episode 998 completed.
# Episode 999 completed.
# Episode 1000 completed.
# Episode 1001 completed.
# Episode 1002 completed.
# Episode 1003 completed.
# Episode 1004 completed.
# Episode 1005 completed.
# Episode 1006 completed.
# Episode 1007 completed.
# Episode 1008 completed.
# Episode 1009 completed.
# Episode 1010 completed.
# Episode 1011 completed.
# Episode 1012 completed.
# Episode 1013 completed.
# Episode 1014 completed.
# Episode 1015 completed.
# Episode 1016 completed.
# Episode 1017 completed.
# Episode 1018 completed.
# Episode 1019 completed.
# Episode 1020 completed.
# Episode 1021 completed.
# Episode 1022 completed.
# Episode 1023 completed.
# Episode 1024 completed.
# Episode 1025 completed.
# Episode 1026 completed.
# Episode 1027 completed.
# Episode 1028 completed.
# Episode 1029 completed.
# Episode 1030 completed.
# Episode 1031 completed.
# Episode 1032 completed.
# Episode 1033 completed.
# Episode 1034 completed.
# Episode 1035 completed.
# Episode 1036 completed.
# Episode 1037 completed.
# Episode 1038 completed.
# Episode 1039 completed.
# Episode 1040 completed.
# Episode 1041 completed.
# Episode 1042 completed.
# Episode 1043 completed.
# Episode 1044 completed.
# Episode 1045 completed.
# Episode 1046 completed.
# Episode 1047 completed.
# Episode 1048 completed.
# Episode 1049 completed.
# Episode 1050 completed.
# Episode 1051 completed.
# Episode 1052 completed.
# Episode 1053 completed.
# Episode 1054 completed.
# Episode 1055 completed.
# Episode 1056 completed.
# Episode 1057 completed.
# Episode 1058 completed.
# Episode 1059 completed.
# Episode 1060 completed.
# Episode 1061 completed.
# Episode 1062 completed.
# Episode 1063 completed.
# Episode 1064 completed.
# Episode 1065 completed.
# Episode 1066 completed.
# Episode 1067 completed.
# Episode 1068 completed.
# Episode 1069 completed.
# Episode 1070 completed.
# Episode 1071 completed.
# Episode 1072 completed.
# Episode 1073 completed.
# Episode 1074 completed.
# Episode 1075 completed.
# Episode 1076 completed.
# Episode 1077 completed.
# Episode 1078 completed.
# Episode 1079 completed.
# Episode 1080 completed.
# Episode 1081 completed.
# Episode 1082 completed.
# Episode 1083 completed.
# Episode 1084 completed.
# Episode 1085 completed.
# Episode 1086 completed.
# Episode 1087 completed.
# Episode 1088 completed.
# Episode 1089 completed.
# Episode 1090 completed.
# Episode 1091 completed.
# Episode 1092 completed.
# Episode 1093 completed.
# Episode 1094 completed.
# Episode 1095 completed.
# Episode 1096 completed.
# Episode 1097 completed.
# Episode 1098 completed.
# Episode 1099 completed.
# Episode 1100 completed.
# Episode 1101 completed.
# Episode 1102 completed.
# Episode 1103 completed.
# Episode 1104 completed.
# Episode 1105 completed.
# Episode 1106 completed.
# Episode 1107 completed.
# Episode 1108 completed.
# Episode 1109 completed.
# Episode 1110 completed.
# Episode 1111 completed.
# Episode 1112 completed.
# Episode 1113 completed.
# Episode 1114 completed.
# Episode 1115 completed.
# Episode 1116 completed.
# Episode 1117 completed.
# Episode 1118 completed.
# Episode 1119 completed.
# Episode 1120 completed.
# Episode 1121 completed.
# Episode 1122 completed.
# Episode 1123 completed.
# Episode 1124 completed.
# Episode 1125 completed.
# Episode 1126 completed.
# Episode 1127 completed.
# Episode 1128 completed.
# Episode 1129 completed.
# Episode 1130 completed.
# Episode 1131 completed.
# Episode 1132 completed.
# Episode 1133 completed.
# Episode 1134 completed.
# Episode 1135 completed.
# Episode 1136 completed.
# Episode 1137 completed.
# Episode 1138 completed.
# Episode 1139 completed.
# Episode 1140 completed.
# Episode 1141 completed.
# Episode 1142 completed.
# Episode 1143 completed.
# Episode 1144 completed.
# Episode 1145 completed.
# Episode 1146 completed.
# Episode 1147 completed.
# Episode 1148 completed.
# Episode 1149 completed.
# Episode 1150 completed.
# Episode 1151 completed.
# Episode 1152 completed.
# Episode 1153 completed.
# Episode 1154 completed.
# Episode 1155 completed.
# Episode 1156 completed.
# Episode 1157 completed.
# Episode 1158 completed.
# Episode 1159 completed.
# Episode 1160 completed.
# Episode 1161 completed.
# Episode 1162 completed.
# Episode 1163 completed.
# Episode 1164 completed.
# Episode 1165 completed.
# Episode 1166 completed.
# Episode 1167 completed.
# Episode 1168 completed.
# Episode 1169 completed.
# Episode 1170 completed.
# Episode 1171 completed.
# Episode 1172 completed.
# Episode 1173 completed.
# Episode 1174 completed.
# Episode 1175 completed.
# Episode 1176 completed.
# Episode 1177 completed.
# Episode 1178 completed.
# Episode 1179 completed.
# Episode 1180 completed.
# Episode 1181 completed.
# Episode 1182 completed.
# Episode 1183 completed.
# Episode 1184 completed.
# Episode 1185 completed.
# Episode 1186 completed.
# Episode 1187 completed.
# Episode 1188 completed.
# Episode 1189 completed.
# Episode 1190 completed.
# Episode 1191 completed.
# Episode 1192 completed.
# Episode 1193 completed.
# Episode 1194 completed.
# Episode 1195 completed.
# Episode 1196 completed.
# Episode 1197 completed.
# Episode 1198 completed.
# Episode 1199 completed.
# Episode 1200 completed.
# Episode 1201 completed.
# Episode 1202 completed.
# Episode 1203 completed.
# Episode 1204 completed.
# Episode 1205 completed.
# Episode 1206 completed.
# Episode 1207 completed.
# Episode 1208 completed.
# Episode 1209 completed.
# Episode 1210 completed.
# Episode 1211 completed.
# Episode 1212 completed.
# Episode 1213 completed.
# Episode 1214 completed.
# Episode 1215 completed.
# Episode 1216 completed.
# Episode 1217 completed.
# Episode 1218 completed.
# Episode 1219 completed.
# Episode 1220 completed.
# Episode 1221 completed.
# Episode 1222 completed.
# Episode 1223 completed.
# Episode 1224 completed.
# Episode 1225 completed.
# Episode 1226 completed.
# Episode 1227 completed.
# Episode 1228 completed.
# Episode 1229 completed.
# Episode 1230 completed.
# Episode 1231 completed.
# Episode 1232 completed.
# Episode 1233 completed.
# Episode 1234 completed.
# Episode 1235 completed.
# Episode 1236 completed.
# Episode 1237 completed.
# Episode 1238 completed.
# Episode 1239 completed.
# Episode 1240 completed.
# Episode 1241 completed.
# Episode 1242 completed.
# Episode 1243 completed.
# Episode 1244 completed.
# Episode 1245 completed.
# Episode 1246 completed.
# Episode 1247 completed.
# Episode 1248 completed.
# Episode 1249 completed.
# Episode 1250 completed.
# Episode 1251 completed.
# Episode 1252 completed.
# Episode 1253 completed.
# Episode 1254 completed.
# Episode 1255 completed.
# Episode 1256 completed.
# Episode 1257 completed.
# Episode 1258 completed.
# Episode 1259 completed.
# Episode 1260 completed.
# Episode 1261 completed.
# Episode 1262 completed.
# Episode 1263 completed.
# Episode 1264 completed.
# Episode 1265 completed.
# Episode 1266 completed.
# Episode 1267 completed.
# Episode 1268 completed.
# Episode 1269 completed.
# Episode 1270 completed.
# Episode 1271 completed.
# Episode 1272 completed.
# Episode 1273 completed.
# Episode 1274 completed.
# Episode 1275 completed.
# Episode 1276 completed.
# Episode 1277 completed.
# Episode 1278 completed.
# Episode 1279 completed.
# Episode 1280 completed.
# Episode 1281 completed.
# Episode 1282 completed.
# Episode 1283 completed.
# Episode 1284 completed.
# Episode 1285 completed.
# Episode 1286 completed.
# Episode 1287 completed.
# Episode 1288 completed.
# Episode 1289 completed.
# Episode 1290 completed.
# Episode 1291 completed.
# Episode 1292 completed.
# Episode 1293 completed.
# Episode 1294 completed.
# Episode 1295 completed.
# Episode 1296 completed.
# Episode 1297 completed.
# Episode 1298 completed.
# Episode 1299 completed.
# Episode 1300 completed.
# Episode 1301 completed.
# Episode 1302 completed.
# Episode 1303 completed.
# Episode 1304 completed.
# Episode 1305 completed.
# Episode 1306 completed.
# Episode 1307 completed.
# Episode 1308 completed.
# Episode 1309 completed.
# Episode 1310 completed.
# Episode 1311 completed.
# Episode 1312 completed.
# Episode 1313 completed.
# Episode 1314 completed.
# Episode 1315 completed.
# Episode 1316 completed.
# Episode 1317 completed.
# Episode 1318 completed.
# Episode 1319 completed.
# Episode 1320 completed.
# Episode 1321 completed.
# Episode 1322 completed.
# Episode 1323 completed.
# Episode 1324 completed.
# Episode 1325 completed.
# Episode 1326 completed.
# Episode 1327 completed.
# Episode 1328 completed.
# Episode 1329 completed.
# Episode 1330 completed.
# Episode 1331 completed.
# Episode 1332 completed.
# Episode 1333 completed.
# Episode 1334 completed.
# Episode 1335 completed.
# Episode 1336 completed.
# Episode 1337 completed.
# Episode 1338 completed.
# Episode 1339 completed.
# Episode 1340 completed.
# Episode 1341 completed.
# Episode 1342 completed.
# Episode 1343 completed.
# Episode 1344 completed.
# Episode 1345 completed.
# Episode 1346 completed.
# Episode 1347 completed.
# Episode 1348 completed.
# Episode 1349 completed.
# Episode 1350 completed.
# Episode 1351 completed.
# Episode 1352 completed.
# Episode 1353 completed.
# Episode 1354 completed.
# Episode 1355 completed.
# Episode 1356 completed.
# Episode 1357 completed.
# Episode 1358 completed.
# Episode 1359 completed.
# Episode 1360 completed.
# Episode 1361 completed.
# Episode 1362 completed.
# Episode 1363 completed.
# Episode 1364 completed.
# Episode 1365 completed.
# Episode 1366 completed.
# Episode 1367 completed.
# Episode 1368 completed.
# Episode 1369 completed.
# Episode 1370 completed.
# Episode 1371 completed.
# Episode 1372 completed.
# Episode 1373 completed.
# Episode 1374 completed.
# Episode 1375 completed.
# Episode 1376 completed.
# Episode 1377 completed.
# Episode 1378 completed.
# Episode 1379 completed.
# Episode 1380 completed.
# Episode 1381 completed.
# Episode 1382 completed.
# Episode 1383 completed.
# Episode 1384 completed.
# Episode 1385 completed.
# Episode 1386 completed.
# Episode 1387 completed.
# Episode 1388 completed.
# Episode 1389 completed.
# Episode 1390 completed.
# Episode 1391 completed.
# Episode 1392 completed.
# Episode 1393 completed.
# Episode 1394 completed.
# Episode 1395 completed.
# Episode 1396 completed.
# Episode 1397 completed.
# Episode 1398 completed.
# Episode 1399 completed.
# Episode 1400 completed.
# Episode 1401 completed.
# Episode 1402 completed.
# Episode 1403 completed.
# Episode 1404 completed.
# Episode 1405 completed.
# Episode 1406 completed.
# Episode 1407 completed.
# Episode 1408 completed.
# Episode 1409 completed.
# Episode 1410 completed.
# Episode 1411 completed.
# Episode 1412 completed.
# Episode 1413 completed.
# Episode 1414 completed.
# Episode 1415 completed.
# Episode 1416 completed.
# Episode 1417 completed.
# Episode 1418 completed.
# Episode 1419 completed.
# Episode 1420 completed.
# Episode 1421 completed.
# Episode 1422 completed.
# Episode 1423 completed.
# Episode 1424 completed.
# Episode 1425 completed.
# Episode 1426 completed.
# Episode 1427 completed.
# Episode 1428 completed.
# Episode 1429 completed.
# Episode 1430 completed.
# Episode 1431 completed.
# Episode 1432 completed.
# Episode 1433 completed.
# Episode 1434 completed.
# Episode 1435 completed.
# Episode 1436 completed.
# Episode 1437 completed.
# Episode 1438 completed.
# Episode 1439 completed.
# Episode 1440 completed.
# Episode 1441 completed.
# Episode 1442 completed.
# Episode 1443 completed.
# Episode 1444 completed.
# Episode 1445 completed.
# Episode 1446 completed.
# Episode 1447 completed.
# Episode 1448 completed.
# Episode 1449 completed.
# Episode 1450 completed.
# Episode 1451 completed.
# Episode 1452 completed.
# Episode 1453 completed.
# Episode 1454 completed.
# Episode 1455 completed.
# Episode 1456 completed.
# Episode 1457 completed.
# Episode 1458 completed.
# Episode 1459 completed.
# Episode 1460 completed.
# Episode 1461 completed.
# Episode 1462 completed.
# Episode 1463 completed.
# Episode 1464 completed.
# Episode 1465 completed.
# Episode 1466 completed.
# Episode 1467 completed.
# Episode 1468 completed.
# Episode 1469 completed.
# Episode 1470 completed.
# Episode 1471 completed.
# Episode 1472 completed.
# Episode 1473 completed.
# Episode 1474 completed.
# Episode 1475 completed.
# Episode 1476 completed.
# Episode 1477 completed.
# Episode 1478 completed.
# Episode 1479 completed.
# Episode 1480 completed.
# Episode 1481 completed.
# Episode 1482 completed.
# Episode 1483 completed.
# Episode 1484 completed.
# Episode 1485 completed.
# Episode 1486 completed.
# Episode 1487 completed.
# Episode 1488 completed.
# Episode 1489 completed.
# Episode 1490 completed.
# Episode 1491 completed.
# Episode 1492 completed.
# Episode 1493 completed.
# Episode 1494 completed.
# Episode 1495 completed.
# Episode 1496 completed.
# Episode 1497 completed.
# Episode 1498 completed.
# Episode 1499 completed.
# Episode 1500 completed.
# Episode 1501 completed.
# Episode 1502 completed.
# Episode 1503 completed.
# Episode 1504 completed.
# Episode 1505 completed.
# Episode 1506 completed.
# Episode 1507 completed.
# Episode 1508 completed.
# Episode 1509 completed.
# Episode 1510 completed.
# Episode 1511 completed.
# Episode 1512 completed.
# Episode 1513 completed.
# Episode 1514 completed.
# Episode 1515 completed.
# Episode 1516 completed.
# Episode 1517 completed.
# Episode 1518 completed.
# Episode 1519 completed.
# Episode 1520 completed.
# Episode 1521 completed.
# Episode 1522 completed.
# Episode 1523 completed.
# Episode 1524 completed.
# Episode 1525 completed.
# Episode 1526 completed.
# Episode 1527 completed.
# Episode 1528 completed.
# Episode 1529 completed.
# Episode 1530 completed.
# Episode 1531 completed.
# Episode 1532 completed.
# Episode 1533 completed.
# Episode 1534 completed.
# Episode 1535 completed.
# Episode 1536 completed.
# Episode 1537 completed.
# Episode 1538 completed.
# Episode 1539 completed.
# Episode 1540 completed.
# Episode 1541 completed.
# Episode 1542 completed.
# Episode 1543 completed.
# Episode 1544 completed.
# Episode 1545 completed.
# Episode 1546 completed.
# Episode 1547 completed.
# Episode 1548 completed.
# Episode 1549 completed.
# Episode 1550 completed.
# Episode 1551 completed.
# Episode 1552 completed.
# Episode 1553 completed.
# Episode 1554 completed.
# Episode 1555 completed.
# Episode 1556 completed.
# Episode 1557 completed.
# Episode 1558 completed.
# Episode 1559 completed.
# Episode 1560 completed.
# Episode 1561 completed.
# Episode 1562 completed.
# Episode 1563 completed.
# Episode 1564 completed.
# Episode 1565 completed.
# Episode 1566 completed.
# Episode 1567 completed.
# Episode 1568 completed.
# Episode 1569 completed.
# Episode 1570 completed.
# Episode 1571 completed.
# Episode 1572 completed.
# Episode 1573 completed.
# Episode 1574 completed.
# Episode 1575 completed.
# Episode 1576 completed.
# Episode 1577 completed.
# Episode 1578 completed.
# Episode 1579 completed.
# Episode 1580 completed.
# Episode 1581 completed.
# Episode 1582 completed.
# Episode 1583 completed.
# Episode 1584 completed.
# Episode 1585 completed.
# Episode 1586 completed.
# Episode 1587 completed.
# Episode 1588 completed.
# Episode 1589 completed.
# Episode 1590 completed.
# Episode 1591 completed.
# Episode 1592 completed.
# Episode 1593 completed.
# Episode 1594 completed.
# Episode 1595 completed.
# Episode 1596 completed.
# Episode 1597 completed.
# Episode 1598 completed.
# Episode 1599 completed.
# Episode 1600 completed.
# Episode 1601 completed.
# Episode 1602 completed.
# Episode 1603 completed.
# Episode 1604 completed.
# Episode 1605 completed.
# Episode 1606 completed.
# Episode 1607 completed.
# Episode 1608 completed.
# Episode 1609 completed.
# Episode 1610 completed.
# Episode 1611 completed.
# Episode 1612 completed.
# Episode 1613 completed.
# Episode 1614 completed.
# Episode 1615 completed.
# Episode 1616 completed.
# Episode 1617 completed.
# Episode 1618 completed.
# Episode 1619 completed.
# Episode 1620 completed.
# Episode 1621 completed.
# Episode 1622 completed.
# Episode 1623 completed.
# Episode 1624 completed.
# Episode 1625 completed.
# Episode 1626 completed.
# Episode 1627 completed.
# Episode 1628 completed.
# Episode 1629 completed.
# Episode 1630 completed.
# Episode 1631 completed.
# Episode 1632 completed.
# Episode 1633 completed.
# Episode 1634 completed.
# Episode 1635 completed.
# Episode 1636 completed.
# Episode 1637 completed.
# Episode 1638 completed.
# Episode 1639 completed.
# Episode 1640 completed.
# Episode 1641 completed.
# Episode 1642 completed.
# Episode 1643 completed.
# Episode 1644 completed.
# Episode 1645 completed.
# Episode 1646 completed.
# Episode 1647 completed.
# Episode 1648 completed.
# Episode 1649 completed.
# Episode 1650 completed.
# Episode 1651 completed.
# Episode 1652 completed.
# Episode 1653 completed.
# Episode 1654 completed.
# Episode 1655 completed.
# Episode 1656 completed.
# Episode 1657 completed.
# Episode 1658 completed.
# Episode 1659 completed.
# Episode 1660 completed.
# Episode 1661 completed.
# Episode 1662 completed.
# Episode 1663 completed.
# Episode 1664 completed.
# Episode 1665 completed.
# Episode 1666 completed.
# Episode 1667 completed.
# Episode 1668 completed.
# Episode 1669 completed.
# Episode 1670 completed.
# Episode 1671 completed.
# Episode 1672 completed.
# Episode 1673 completed.
# Episode 1674 completed.
# Episode 1675 completed.
# Episode 1676 completed.
# Episode 1677 completed.
# Episode 1678 completed.
# Episode 1679 completed.
# Episode 1680 completed.
# Episode 1681 completed.
# Episode 1682 completed.
# Episode 1683 completed.
# Episode 1684 completed.
# Episode 1685 completed.
# Episode 1686 completed.
# Episode 1687 completed.
# Episode 1688 completed.
# Episode 1689 completed.
# Episode 1690 completed.
# Episode 1691 completed.
# Episode 1692 completed.
# Episode 1693 completed.
# Episode 1694 completed.
# Episode 1695 completed.
# Episode 1696 completed.
# Episode 1697 completed.
# Episode 1698 completed.
# Episode 1699 completed.
# Episode 1700 completed.
# Episode 1701 completed.
# Episode 1702 completed.
# Episode 1703 completed.
# Episode 1704 completed.
# Episode 1705 completed.
# Episode 1706 completed.
# Episode 1707 completed.
# Episode 1708 completed.
# Episode 1709 completed.
# Episode 1710 completed.
# Episode 1711 completed.
# Episode 1712 completed.
# Episode 1713 completed.
# Episode 1714 completed.
# Episode 1715 completed.
# Episode 1716 completed.
# Episode 1717 completed.
# Episode 1718 completed.
# Episode 1719 completed.
# Episode 1720 completed.
# Episode 1721 completed.
# Episode 1722 completed.
# Episode 1723 completed.
# Episode 1724 completed.
# Episode 1725 completed.
# Episode 1726 completed.
# Episode 1727 completed.
# Episode 1728 completed.
# Episode 1729 completed.
# Episode 1730 completed.
# Episode 1731 completed.
# Episode 1732 completed.
# Episode 1733 completed.
# Episode 1734 completed.
# Episode 1735 completed.
# Episode 1736 completed.
# Episode 1737 completed.
# Episode 1738 completed.
# Episode 1739 completed.
# Episode 1740 completed.
# Episode 1741 completed.
# Episode 1742 completed.
# Episode 1743 completed.
# Episode 1744 completed.
# Episode 1745 completed.
# Episode 1746 completed.
# Episode 1747 completed.
# Episode 1748 completed.
# Episode 1749 completed.
# Episode 1750 completed.
# Episode 1751 completed.
# Episode 1752 completed.
# Episode 1753 completed.
# Episode 1754 completed.
# Episode 1755 completed.
# Episode 1756 completed.
# Episode 1757 completed.
# Episode 1758 completed.
# Episode 1759 completed.
# Episode 1760 completed.
# Episode 1761 completed.
# Episode 1762 completed.
# Episode 1763 completed.
# Episode 1764 completed.
# Episode 1765 completed.
# Episode 1766 completed.
# Episode 1767 completed.
# Episode 1768 completed.
# Episode 1769 completed.
# Episode 1770 completed.
# Episode 1771 completed.
# Episode 1772 completed.
# Episode 1773 completed.
# Episode 1774 completed.
# Episode 1775 completed.
# Episode 1776 completed.
# Episode 1777 completed.
# Episode 1778 completed.
# Episode 1779 completed.
# Episode 1780 completed.
# Episode 1781 completed.
# Episode 1782 completed.
# Episode 1783 completed.
# Episode 1784 completed.
# Episode 1785 completed.
# Episode 1786 completed.
# Episode 1787 completed.
# Episode 1788 completed.
# Episode 1789 completed.
# Episode 1790 completed.
# Episode 1791 completed.
# Episode 1792 completed.
# Episode 1793 completed.
# Episode 1794 completed.
# Episode 1795 completed.
# Episode 1796 completed.
# Episode 1797 completed.
# Episode 1798 completed.
# Episode 1799 completed.
# Episode 1800 completed.
# Episode 1801 completed.
# Episode 1802 completed.
# Episode 1803 completed.
# Episode 1804 completed.
# Episode 1805 completed.
# Episode 1806 completed.
# Episode 1807 completed.
# Episode 1808 completed.
# Episode 1809 completed.
# Episode 1810 completed.
# Episode 1811 completed.
# Episode 1812 completed.
# Episode 1813 completed.
# Episode 1814 completed.
# Episode 1815 completed.
# Episode 1816 completed.
# Episode 1817 completed.
# Episode 1818 completed.
# Episode 1819 completed.
# Episode 1820 completed.
# Episode 1821 completed.
# Episode 1822 completed.
# Episode 1823 completed.
# Episode 1824 completed.
# Episode 1825 completed.
# Episode 1826 completed.
# Episode 1827 completed.
# Episode 1828 completed.
# Episode 1829 completed.
# Episode 1830 completed.
# Episode 1831 completed.
# Episode 1832 completed.
# Episode 1833 completed.
# Episode 1834 completed.
# Episode 1835 completed.
# Episode 1836 completed.
# Episode 1837 completed.
# Episode 1838 completed.
# Episode 1839 completed.
# Episode 1840 completed.
# Episode 1841 completed.
# Episode 1842 completed.
# Episode 1843 completed.
# Episode 1844 completed.
# Episode 1845 completed.
# Episode 1846 completed.
# Episode 1847 completed.
# Episode 1848 completed.
# Episode 1849 completed.
# Episode 1850 completed.
# Episode 1851 completed.
# Episode 1852 completed.
# Episode 1853 completed.
# Episode 1854 completed.
# Episode 1855 completed.
# Episode 1856 completed.
# Episode 1857 completed.
# Episode 1858 completed.
# Episode 1859 completed.
# Episode 1860 completed.
# Episode 1861 completed.
# Episode 1862 completed.
# Episode 1863 completed.
# Episode 1864 completed.
# Episode 1865 completed.
# Episode 1866 completed.
# Episode 1867 completed.
# Episode 1868 completed.
# Episode 1869 completed.
# Episode 1870 completed.
# Episode 1871 completed.
# Episode 1872 completed.
# Episode 1873 completed.
# Episode 1874 completed.
# Episode 1875 completed.
# Episode 1876 completed.
# Episode 1877 completed.
# Episode 1878 completed.
# Episode 1879 completed.
# Episode 1880 completed.
# Episode 1881 completed.
# Episode 1882 completed.
# Episode 1883 completed.
# Episode 1884 completed.
# Episode 1885 completed.
# Episode 1886 completed.
# Episode 1887 completed.
# Episode 1888 completed.
# Episode 1889 completed.
# Episode 1890 completed.
# Episode 1891 completed.
# Episode 1892 completed.
# Episode 1893 completed.
# Episode 1894 completed.
# Episode 1895 completed.
# Episode 1896 completed.
# Episode 1897 completed.
# Episode 1898 completed.
# Episode 1899 completed.
# Episode 1900 completed.
# Episode 1901 completed.
# Episode 1902 completed.
# Episode 1903 completed.
# Episode 1904 completed.
# Episode 1905 completed.
# Episode 1906 completed.
# Episode 1907 completed.
# Episode 1908 completed.
# Episode 1909 completed.
# Episode 1910 completed.
# Episode 1911 completed.
# Episode 1912 completed.
# Episode 1913 completed.
# Episode 1914 completed.
# Episode 1915 completed.
# Episode 1916 completed.
# Episode 1917 completed.
# Episode 1918 completed.
# Episode 1919 completed.
# Episode 1920 completed.
# Episode 1921 completed.
# Episode 1922 completed.
# Episode 1923 completed.
# Episode 1924 completed.
# Episode 1925 completed.
# Episode 1926 completed.
# Episode 1927 completed.
# Episode 1928 completed.
# Episode 1929 completed.
# Episode 1930 completed.
# Episode 1931 completed.
# Episode 1932 completed.
# Episode 1933 completed.
# Episode 1934 completed.
# Episode 1935 completed.
# Episode 1936 completed.
# Episode 1937 completed.
# Episode 1938 completed.
# Episode 1939 completed.
# Episode 1940 completed.
# Episode 1941 completed.
# Episode 1942 completed.
# Episode 1943 completed.
# Episode 1944 completed.
# Episode 1945 completed.
# Episode 1946 completed.
# Episode 1947 completed.
# Episode 1948 completed.
# Episode 1949 completed.
# Episode 1950 completed.
# Episode 1951 completed.
# Episode 1952 completed.
# Episode 1953 completed.
# Episode 1954 completed.
# Episode 1955 completed.
# Episode 1956 completed.
# Episode 1957 completed.
# Episode 1958 completed.
# Episode 1959 completed.
# Episode 1960 completed.
# Episode 1961 completed.
# Episode 1962 completed.
# Episode 1963 completed.
# Episode 1964 completed.
# Episode 1965 completed.
# Episode 1966 completed.
# Episode 1967 completed.
# Episode 1968 completed.
# Episode 1969 completed.
# Episode 1970 completed.
# Episode 1971 completed.
# Episode 1972 completed.
# Episode 1973 completed.
# Episode 1974 completed.
# Episode 1975 completed.
# Episode 1976 completed.
# Episode 1977 completed.
# Episode 1978 completed.
# Episode 1979 completed.
# Episode 1980 completed.
# Episode 1981 completed.
# Episode 1982 completed.
# Episode 1983 completed.
# Episode 1984 completed.
# Episode 1985 completed.
# Episode 1986 completed.
# Episode 1987 completed.
# Episode 1988 completed.
# Episode 1989 completed.
# Episode 1990 completed.
# Episode 1991 completed.
# Episode 1992 completed.
# Episode 1993 completed.
# Episode 1994 completed.
# Episode 1995 completed.
# Episode 1996 completed.
# Episode 1997 completed.
# Episode 1998 completed.
# Episode 1999 completed.
# Episode 2000 completed.
# Episode 2001 completed.
# Episode 2002 completed.
# Episode 2003 completed.
# Episode 2004 completed.
# Episode 2005 completed.
# Episode 2006 completed.
# Episode 2007 completed.
# Episode 2008 completed.
# Episode 2009 completed.
# Episode 2010 completed.
# Episode 2011 completed.
# Episode 2012 completed.
# Episode 2013 completed.
# Episode 2014 completed.
# Episode 2015 completed.
# Episode 2016 completed.
# Episode 2017 completed.
# Episode 2018 completed.
# Episode 2019 completed.
# Episode 2020 completed.
# Episode 2021 completed.
# Episode 2022 completed.
# Episode 2023 completed.
# Episode 2024 completed.
# Episode 2025 completed.
# Episode 2026 completed.
# Episode 2027 completed.
# Episode 2028 completed.
# Episode 2029 completed.
# Episode 2030 completed.
# Episode 2031 completed.
# Episode 2032 completed.
# Episode 2033 completed.
# Episode 2034 completed.
# Episode 2035 completed.
# Episode 2036 completed.
# Episode 2037 completed.
# Episode 2038 completed.
# Episode 2039 completed.
# Episode 2040 completed.
# Episode 2041 completed.
# Episode 2042 completed.
# Episode 2043 completed.
# Episode 2044 completed.
# Episode 2045 completed.
# Episode 2046 completed.
# ...
# Episode 9335 completed.
# Episode 9336 completed.
# Episode 9337 completed.
# Episode 9338 completed.
# Episode 9339 completed.
# Episode 9340 completed.
# Episode 9341 completed.
# Episode 9342 completed.
# Episode 9343 completed.
# Episode 9344 completed.
# Episode 9345 completed.
# Episode 9346 completed.
# Episode 9347 completed.
# Episode 9348 completed.
# Episode 9349 completed.
# Episode 9350 completed.
# Episode 9351 completed.
# Episode 9352 completed.
# Episode 9353 completed.
# Episode 9354 completed.
# Episode 9355 completed.
# Episode 9356 completed.
# Episode 9357 completed.
# Episode 9358 completed.
# Episode 9359 completed.
# Episode 9360 completed.
# Episode 9361 completed.
# Episode 9362 completed.
# Episode 9363 completed.
# Episode 9364 completed.
# Episode 9365 completed.
# Episode 9366 completed.
# Episode 9367 completed.
# Episode 9368 completed.
# Episode 9369 completed.
# Episode 9370 completed.
# Episode 9371 completed.
# Episode 9372 completed.
# Episode 9373 completed.
# Episode 9374 completed.
# Episode 9375 completed.
# Episode 9376 completed.
# Episode 9377 completed.
# Episode 9378 completed.
# Episode 9379 completed.
# Episode 9380 completed.
# Episode 9381 completed.
# Episode 9382 completed.
# Episode 9383 completed.
# Episode 9384 completed.
# Episode 9385 completed.
# Episode 9386 completed.
# Episode 9387 completed.
# Episode 9388 completed.
# Episode 9389 completed.
# Episode 9390 completed.
# Episode 9391 completed.
# Episode 9392 completed.
# Episode 9393 completed.
# Episode 9394 completed.
# Episode 9395 completed.
# Episode 9396 completed.
# Episode 9397 completed.
# Episode 9398 completed.
# Episode 9399 completed.
# Episode 9400 completed.
# Episode 9401 completed.
# Episode 9402 completed.
# Episode 9403 completed.
# Episode 9404 completed.
# Episode 9405 completed.
# Episode 9406 completed.
# Episode 9407 completed.
# Episode 9408 completed.
# Episode 9409 completed.
# Episode 9410 completed.
# Episode 9411 completed.
# Episode 9412 completed.
# Episode 9413 completed.
# Episode 9414 completed.
# Episode 9415 completed.
# Episode 9416 completed.
# Episode 9417 completed.
# Episode 9418 completed.
# Episode 9419 completed.
# Episode 9420 completed.
# Episode 9421 completed.
# Episode 9422 completed.
# Episode 9423 completed.
# Episode 9424 completed.
# Episode 9425 completed.
# Episode 9426 completed.
# Episode 9427 completed.
# Episode 9428 completed.
# Episode 9429 completed.
# Episode 9430 completed.
# Episode 9431 completed.
# Episode 9432 completed.
# Episode 9433 completed.
# Episode 9434 completed.
# Episode 9435 completed.
# Episode 9436 completed.
# Episode 9437 completed.
# Episode 9438 completed.
# Episode 9439 completed.
# Episode 9440 completed.
# Episode 9441 completed.
# Episode 9442 completed.
# Episode 9443 completed.
# Episode 9444 completed.
# Episode 9445 completed.
# Episode 9446 completed.
# Episode 9447 completed.
# Episode 9448 completed.
# Episode 9449 completed.
# Episode 9450 completed.
# Episode 9451 completed.
# Episode 9452 completed.
# Episode 9453 completed.
# Episode 9454 completed.
# Episode 9455 completed.
# Episode 9456 completed.
# Episode 9457 completed.
# Episode 9458 completed.
# Episode 9459 completed.
# Episode 9460 completed.
# Episode 9461 completed.
# Episode 9462 completed.
# Episode 9463 completed.
# Episode 9464 completed.
# Episode 9465 completed.
# Episode 9466 completed.
# Episode 9467 completed.
# Episode 9468 completed.
# Episode 9469 completed.
# Episode 9470 completed.
# Episode 9471 completed.
# Episode 9472 completed.
# Episode 9473 completed.
# Episode 9474 completed.
# Episode 9475 completed.
# Episode 9476 completed.
# Episode 9477 completed.
# Episode 9478 completed.
# Episode 9479 completed.
# Episode 9480 completed.
# Episode 9481 completed.
# Episode 9482 completed.
# Episode 9483 completed.
# Episode 9484 completed.
# Episode 9485 completed.
# Episode 9486 completed.
# Episode 9487 completed.
# Episode 9488 completed.
# Episode 9489 completed.
# Episode 9490 completed.
# Episode 9491 completed.
# Episode 9492 completed.
# Episode 9493 completed.
# Episode 9494 completed.
# Episode 9495 completed.
# Episode 9496 completed.
# Episode 9497 completed.
# Episode 9498 completed.
# Episode 9499 completed.
# Episode 9500 completed.
# Episode 9501 completed.
# Episode 9502 completed.
# Episode 9503 completed.
# Episode 9504 completed.
# Episode 9505 completed.
# Episode 9506 completed.
# Episode 9507 completed.
# Episode 9508 completed.
# Episode 9509 completed.
# Episode 9510 completed.
# Episode 9511 completed.
# Episode 9512 completed.
# Episode 9513 completed.
# Episode 9514 completed.
# Episode 9515 completed.
# Episode 9516 completed.
# Episode 9517 completed.
# Episode 9518 completed.
# Episode 9519 completed.
# Episode 9520 completed.
# Episode 9521 completed.
# Episode 9522 completed.
# Episode 9523 completed.
# Episode 9524 completed.
# Episode 9525 completed.
# Episode 9526 completed.
# Episode 9527 completed.
# Episode 9528 completed.
# Episode 9529 completed.
# Episode 9530 completed.
# Episode 9531 completed.
# Episode 9532 completed.
# Episode 9533 completed.
# Episode 9534 completed.
# Episode 9535 completed.
# Episode 9536 completed.
# Episode 9537 completed.
# Episode 9538 completed.
# Episode 9539 completed.
# Episode 9540 completed.
# Episode 9541 completed.
# Episode 9542 completed.
# Episode 9543 completed.
# Episode 9544 completed.
# Episode 9545 completed.
# Episode 9546 completed.
# Episode 9547 completed.
# Episode 9548 completed.
# Episode 9549 completed.
# Episode 9550 completed.
# Episode 9551 completed.
# Episode 9552 completed.
# Episode 9553 completed.
# Episode 9554 completed.
# Episode 9555 completed.
# Episode 9556 completed.
# Episode 9557 completed.
# Episode 9558 completed.
# Episode 9559 completed.
# Episode 9560 completed.
# Episode 9561 completed.
# Episode 9562 completed.
# Episode 9563 completed.
# Episode 9564 completed.
# Episode 9565 completed.
# Episode 9566 completed.
# Episode 9567 completed.
# Episode 9568 completed.
# Episode 9569 completed.
# Episode 9570 completed.
# Episode 9571 completed.
# Episode 9572 completed.
# Episode 9573 completed.
# Episode 9574 completed.
# Episode 9575 completed.
# Episode 9576 completed.
# Episode 9577 completed.
# Episode 9578 completed.
# Episode 9579 completed.
# Episode 9580 completed.
# Episode 9581 completed.
# Episode 9582 completed.
# Episode 9583 completed.
# Episode 9584 completed.
# Episode 9585 completed.
# Episode 9586 completed.
# Episode 9587 completed.
# Episode 9588 completed.
# Episode 9589 completed.
# Episode 9590 completed.
# Episode 9591 completed.
# Episode 9592 completed.
# Episode 9593 completed.
# Episode 9594 completed.
# Episode 9595 completed.
# Episode 9596 completed.
# Episode 9597 completed.
# Episode 9598 completed.
# Episode 9599 completed.
# Episode 9600 completed.
# Episode 9601 completed.
# Episode 9602 completed.
# Episode 9603 completed.
# Episode 9604 completed.
# Episode 9605 completed.
# Episode 9606 completed.
# Episode 9607 completed.
# Episode 9608 completed.
# Episode 9609 completed.
# Episode 9610 completed.
# Episode 9611 completed.
# Episode 9612 completed.
# Episode 9613 completed.
# Episode 9614 completed.
# Episode 9615 completed.
# Episode 9616 completed.
# Episode 9617 completed.
# Episode 9618 completed.
# Episode 9619 completed.
# Episode 9620 completed.
# Episode 9621 completed.
# Episode 9622 completed.
# Episode 9623 completed.
# Episode 9624 completed.
# Episode 9625 completed.
# Episode 9626 completed.
# Episode 9627 completed.
# Episode 9628 completed.
# Episode 9629 completed.
# Episode 9630 completed.
# Episode 9631 completed.
# Episode 9632 completed.
# Episode 9633 completed.
# Episode 9634 completed.
# Episode 9635 completed.
# Episode 9636 completed.
# Episode 9637 completed.
# Episode 9638 completed.
# Episode 9639 completed.
# Episode 9640 completed.
# Episode 9641 completed.
# Episode 9642 completed.
# Episode 9643 completed.
# Episode 9644 completed.
# Episode 9645 completed.
# Episode 9646 completed.
# Episode 9647 completed.
# Episode 9648 completed.
# Episode 9649 completed.
# Episode 9650 completed.
# Episode 9651 completed.
# Episode 9652 completed.
# Episode 9653 completed.
# Episode 9654 completed.
# Episode 9655 completed.
# Episode 9656 completed.
# Episode 9657 completed.
# Episode 9658 completed.
# Episode 9659 completed.
# Episode 9660 completed.
# Episode 9661 completed.
# Episode 9662 completed.
# Episode 9663 completed.
# Episode 9664 completed.
# Episode 9665 completed.
# Episode 9666 completed.
# Episode 9667 completed.
# Episode 9668 completed.
# Episode 9669 completed.
# Episode 9670 completed.
# Episode 9671 completed.
# Episode 9672 completed.
# Episode 9673 completed.
# Episode 9674 completed.
# Episode 9675 completed.
# Episode 9676 completed.
# Episode 9677 completed.
# Episode 9678 completed.
# Episode 9679 completed.
# Episode 9680 completed.
# Episode 9681 completed.
# Episode 9682 completed.
# Episode 9683 completed.
# Episode 9684 completed.
# Episode 9685 completed.
# Episode 9686 completed.
# Episode 9687 completed.
# Episode 9688 completed.
# Episode 9689 completed.
# Episode 9690 completed.
# Episode 9691 completed.
# Episode 9692 completed.
# Episode 9693 completed.
# Episode 9694 completed.
# Episode 9695 completed.
# Episode 9696 completed.
# Episode 9697 completed.
# Episode 9698 completed.
# Episode 9699 completed.
# Episode 9700 completed.
# Episode 9701 completed.
# Episode 9702 completed.
# Episode 9703 completed.
# Episode 9704 completed.
# Episode 9705 completed.
# Episode 9706 completed.
# Episode 9707 completed.
# Episode 9708 completed.
# Episode 9709 completed.
# Episode 9710 completed.
# Episode 9711 completed.
# Episode 9712 completed.
# Episode 9713 completed.
# Episode 9714 completed.
# Episode 9715 completed.
# Episode 9716 completed.
# Episode 9717 completed.
# Episode 9718 completed.
# Episode 9719 completed.
# Episode 9720 completed.
# Episode 9721 completed.
# Episode 9722 completed.
# Episode 9723 completed.
# Episode 9724 completed.
# Episode 9725 completed.
# Episode 9726 completed.
# Episode 9727 completed.
# Episode 9728 completed.
# Episode 9729 completed.
# Episode 9730 completed.
# Episode 9731 completed.
# Episode 9732 completed.
# Episode 9733 completed.
# Episode 9734 completed.
# Episode 9735 completed.
# Episode 9736 completed.
# Episode 9737 completed.
# Episode 9738 completed.
# Episode 9739 completed.
# Episode 9740 completed.
# Episode 9741 completed.
# Episode 9742 completed.
# Episode 9743 completed.
# Episode 9744 completed.
# Episode 9745 completed.
# Episode 9746 completed.
# Episode 9747 completed.
# Episode 9748 completed.
# Episode 9749 completed.
# Episode 9750 completed.
# Episode 9751 completed.
# Episode 9752 completed.
# Episode 9753 completed.
# Episode 9754 completed.
# Episode 9755 completed.
# Episode 9756 completed.
# Episode 9757 completed.
# Episode 9758 completed.
# Episode 9759 completed.
# Episode 9760 completed.
# Episode 9761 completed.
# Episode 9762 completed.
# Episode 9763 completed.
# Episode 9764 completed.
# Episode 9765 completed.
# Episode 9766 completed.
# Episode 9767 completed.
# Episode 9768 completed.
# Episode 9769 completed.
# Episode 9770 completed.
# Episode 9771 completed.
# Episode 9772 completed.
# Episode 9773 completed.
# Episode 9774 completed.
# Episode 9775 completed.
# Episode 9776 completed.
# Episode 9777 completed.
# Episode 9778 completed.
# Episode 9779 completed.
# Episode 9780 completed.
# Episode 9781 completed.
# Episode 9782 completed.
# Episode 9783 completed.
# Episode 9784 completed.
# Episode 9785 completed.
# Episode 9786 completed.
# Episode 9787 completed.
# Episode 9788 completed.
# Episode 9789 completed.
# Episode 9790 completed.
# Episode 9791 completed.
# Episode 9792 completed.
# Episode 9793 completed.
# Episode 9794 completed.
# Episode 9795 completed.
# Episode 9796 completed.
# Episode 9797 completed.
# Episode 9798 completed.
# Episode 9799 completed.
# Episode 9800 completed.
# Episode 9801 completed.
# Episode 9802 completed.
# Episode 9803 completed.
# Episode 9804 completed.
# Episode 9805 completed.
# Episode 9806 completed.
# Episode 9807 completed.
# Episode 9808 completed.
# Episode 9809 completed.
# Episode 9810 completed.
# Episode 9811 completed.
# Episode 9812 completed.
# Episode 9813 completed.
# Episode 9814 completed.
# Episode 9815 completed.
# Episode 9816 completed.
# Episode 9817 completed.
# Episode 9818 completed.
# Episode 9819 completed.
# Episode 9820 completed.
# Episode 9821 completed.
# Episode 9822 completed.
# Episode 9823 completed.
# Episode 9824 completed.
# Episode 9825 completed.
# Episode 9826 completed.
# Episode 9827 completed.
# Episode 9828 completed.
# Episode 9829 completed.
# Episode 9830 completed.
# Episode 9831 completed.
# Episode 9832 completed.
# Episode 9833 completed.
# Episode 9834 completed.
# Episode 9835 completed.
# Episode 9836 completed.
# Episode 9837 completed.
# Episode 9838 completed.
# Episode 9839 completed.
# Episode 9840 completed.
# Episode 9841 completed.
# Episode 9842 completed.
# Episode 9843 completed.
# Episode 9844 completed.
# Episode 9845 completed.
# Episode 9846 completed.
# Episode 9847 completed.
# Episode 9848 completed.
# Episode 9849 completed.
# Episode 9850 completed.
# Episode 9851 completed.
# Episode 9852 completed.
# Episode 9853 completed.
# Episode 9854 completed.
# Episode 9855 completed.
# Episode 9856 completed.
# Episode 9857 completed.
# Episode 9858 completed.
# Episode 9859 completed.
# Episode 9860 completed.
# Episode 9861 completed.
# Episode 9862 completed.
# Episode 9863 completed.
# Episode 9864 completed.
# Episode 9865 completed.
# Episode 9866 completed.
# Episode 9867 completed.
# Episode 9868 completed.
# Episode 9869 completed.
# Episode 9870 completed.
# Episode 9871 completed.
# Episode 9872 completed.
# Episode 9873 completed.
# Episode 9874 completed.
# Episode 9875 completed.
# Episode 9876 completed.
# Episode 9877 completed.
# Episode 9878 completed.
# Episode 9879 completed.
# Episode 9880 completed.
# Episode 9881 completed.
# Episode 9882 completed.
# Episode 9883 completed.
# Episode 9884 completed.
# Episode 9885 completed.
# Episode 9886 completed.
# Episode 9887 completed.
# Episode 9888 completed.
# Episode 9889 completed.
# Episode 9890 completed.
# Episode 9891 completed.
# Episode 9892 completed.
# Episode 9893 completed.
# Episode 9894 completed.
# Episode 9895 completed.
# Episode 9896 completed.
# Episode 9897 completed.
# Episode 9898 completed.
# Episode 9899 completed.
# Episode 9900 completed.
# Episode 9901 completed.
# Episode 9902 completed.
# Episode 9903 completed.
# Episode 9904 completed.
# Episode 9905 completed.
# Episode 9906 completed.
# Episode 9907 completed.
# Episode 9908 completed.
# Episode 9909 completed.
# Episode 9910 completed.
# Episode 9911 completed.
# Episode 9912 completed.
# Episode 9913 completed.
# Episode 9914 completed.
# Episode 9915 completed.
# Episode 9916 completed.
# Episode 9917 completed.
# Episode 9918 completed.
# Episode 9919 completed.
# Episode 9920 completed.
# Episode 9921 completed.
# Episode 9922 completed.
# Episode 9923 completed.
# Episode 9924 completed.
# Episode 9925 completed.
# Episode 9926 completed.
# Episode 9927 completed.
# Episode 9928 completed.
# Episode 9929 completed.
# Episode 9930 completed.
# Episode 9931 completed.
# Episode 9932 completed.
# Episode 9933 completed.
# Episode 9934 completed.
# Episode 9935 completed.
# Episode 9936 completed.
# Episode 9937 completed.
# Episode 9938 completed.
# Episode 9939 completed.
# Episode 9940 completed.
# Episode 9941 completed.
# Episode 9942 completed.
# Episode 9943 completed.
# Episode 9944 completed.
# Episode 9945 completed.
# Episode 9946 completed.
# Episode 9947 completed.
# Episode 9948 completed.
# Episode 9949 completed.
# Episode 9950 completed.
# Episode 9951 completed.
# Episode 9952 completed.
# Episode 9953 completed.
# Episode 9954 completed.
# Episode 9955 completed.
# Episode 9956 completed.
# Episode 9957 completed.
# Episode 9958 completed.
# Episode 9959 completed.
# Episode 9960 completed.
# Episode 9961 completed.
# Episode 9962 completed.
# Episode 9963 completed.
# Episode 9964 completed.
# Episode 9965 completed.
# Episode 9966 completed.
# Episode 9967 completed.
# Episode 9968 completed.
# Episode 9969 completed.
# Episode 9970 completed.
# Episode 9971 completed.
# Episode 9972 completed.
# Episode 9973 completed.
# Episode 9974 completed.
# Episode 9975 completed.
# Episode 9976 completed.
# Episode 9977 completed.
# Episode 9978 completed.
# Episode 9979 completed.
# Episode 9980 completed.
# Episode 9981 completed.
# Episode 9982 completed.
# Episode 9983 completed.
# Episode 9984 completed.
# Episode 9985 completed.
# Episode 9986 completed.
# Episode 9987 completed.
# Episode 9988 completed.
# Episode 9989 completed.
# Episode 9990 completed.
# Episode 9991 completed.
# Episode 9992 completed.
# Episode 9993 completed.
# Episode 9994 completed.
# Episode 9995 completed.
# Episode 9996 completed.
# Episode 9997 completed.
# Episode 9998 completed.
# Episode 9999 completed.
# Episode 10000 completed.

# %%
# Before starting the game loop
# Load the trained model (if it exists)
def load_model(agent, filename="tictactoe_dqn_model.pth"):
    try:
        agent.model.load_state_dict(torch.load(filename))
        agent.model.eval()  # Set the model to evaluation mode
        print(f"Model loaded from {filename}")
    except FileNotFoundError:
        print(f"No model found at {filename}. Starting fresh.")

# %%
# Main Game Loop
game = TicTacToe()
root = Node(state=game.clone(), player=1)

use_mcts = False  # Set to False to use DQN
agent = DQNAgent(input_dim=9, output_dim=9)  # 9 possible moves for a 3x3 Tic-Tac-Toe board
load_model(agent)  # Load the trained model (if exists)

while True:
    game.display_board()

    # Check if the game is over
    winner = game.check_winner()
    if winner is not None:
        if winner == 0:
            print("It's a draw!")
        else:
            print(f"Player {'X' if winner == 1 else 'O'} wins!")
        # Save the model after the game ends
        torch.save(agent.model.state_dict(), 'tictactoe_dqn_model.pth')  # Save the model here
        break  # Exit the game loop

    if game.current_player == 1:  # Player's turn
        print("Your turn (Player X). Enter row and column (0-2):")
        row, col = map(int, input().split())
        if game.make_move(row, col, 1):
            root = Node(state=game.clone(), player=-1)  # Update root for AI
            game.current_player = -1  # Switch to AI
        else:
            print("Invalid move. Try again.")
    else:  # AI's turn
        print("AI's turn (Player O).")

        # Use DQN to determine the best move
        state = game.board.flatten()  # Flatten the board state to 1D for DQN input
        action = agent.select_action(state)  # Get the best move from the DQN agent

        # Convert the action from the flattened index to row and column
        row, col = divmod(action, 3)

        # Apply the move to the game board
        valid_move = game.make_move(row, col, -1)  # AI is Player -1

        if valid_move:
            # Check if the game is over (win, loss, or draw)
            winner = game.check_winner()
            done = winner is not None  # End the game if there's a winner or draw
            reward = 1 if winner == -1 else -1 if winner == 1 else 0

            # Store the experience and train the DQN model
            next_state = game.board.flatten()
            agent.store_experience(state, action, reward, next_state, done)
            agent.train()  # Train the model with the stored experience

        game.current_player = 1  # Switch back to player
# Out:
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_47554/2931976256.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent.model.load_state_dict(torch.load(filename))
# Model loaded from tictactoe_dqn_model.pth
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Your turn (Player X). Enter row and column (0-2):
#  1 1
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# AI's turn (Player O).
#   |   |
# ---------
# O | X |
# ---------
#   |   |
# ---------
# Your turn (Player X). Enter row and column (0-2):
#  0 0
# X |   |
# ---------
# O | X |
# ---------
#   |   |
# ---------
# AI's turn (Player O).
# X |   |
# ---------
# O | X | O
# ---------
#   |   |
# ---------
# Your turn (Player X). Enter row and column (0-2):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 25
#      23 if game.current_player == 1:  # Player's turn
#      24     print("Your turn (Player X). Enter row and column (0-2):")
# ---> 25     row, col = map(int, input().split())
#      26     if game.make_move(row, col, 1):
#      27         root = Node(state=game.clone(), player=-1)  # Update root for AI
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
